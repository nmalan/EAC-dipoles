# %%
import xarray as xr
import pandas as pd
import numpy as np
import matplotlib.dates as mdates
import cmocean 
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import matplotlib.ticker as mticker
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## load data to xarray, slice in time, and then convert to pandas dataframe

# %%
glid_path = '/home/z3526974/Work/data/Glider_data/IMOS_ANFOG_BCEOPSTUV_20170911T071056Z_SL287_FV01_timeseries_END-20171002T010328Z.nc'  

ds = xr.open_dataset(glid_path)

ts = ds.sel(TIME=slice('2017-09-16', '2017-09-23'))

# Get onshore and offshore segments
g1 = ds.sel(TIME=slice('2017-09-16T00:00:00', '2017-09-16T13:00:00'))
g2 = ds.sel(TIME=slice('2017-09-16T13:00:00', '2017-09-17T20:00:00'))
g3 = ds.sel(TIME=slice('2017-09-17T19:00:00', '2017-09-18T09:00:00'))
g4 = ds.sel(TIME=slice('2017-09-18T09:00:00', '2017-09-19T01:00:00'))
g5 = ds.sel(TIME=slice('2017-09-19T01:00:00', '2017-09-20T05:00:00'))
g6 = ds.sel(TIME=slice('2017-09-20T05:00:00', '2017-09-21T18:00:00'))
g7 = ds.sel(TIME=slice('2017-09-21T18:00:00', '2017-09-24T00:00:00'))

df = xr.Dataset.to_dataframe(ts)
ds
# Out:
# <xarray.Dataset>
# Dimensions:                    (TIME: 852819)
# Coordinates:
#   * TIME                       (TIME) datetime64[ns] 2017-09-11T07:10:56.356333824 ... 2017-10-02T01:03:28.628808704
#     LATITUDE                   (TIME) float64 ...
#     LONGITUDE                  (TIME) float64 ...
#     DEPTH                      (TIME) float64 ...
# Data variables:
#     PLATFORM                   |S1 ...
#     DEPLOYMENT                 |S1 ...
#     SENSOR1                    |S1 ...
#     SENSOR2                    |S1 ...
#     SENSOR3                    |S1 ...
#     SENSOR4                    |S1 ...
#     TIME_quality_control       (TIME) float32 ...
#     LATITUDE_quality_control   (TIME) float32 ...
#     LONGITUDE_quality_control  (TIME) float32 ...
#     HEAD                       (TIME) float64 ...
#     HEAD_quality_control       (TIME) float32 ...
#     UCUR                       (TIME) float64 ...
#     UCUR_quality_control       (TIME) float32 ...
#     VCUR                       (TIME) float64 ...
#     VCUR_quality_control       (TIME) float32 ...
#     UCUR_GPS                   (TIME) float64 ...
#     UCUR_GPS_quality_control   (TIME) float32 ...
#     VCUR_GPS                   (TIME) float64 ...
#     VCUR_GPS_quality_control   (TIME) float32 ...
#     PHASE                      (TIME) float32 ...
#     PHASE_quality_control      (TIME) float32 ...
#     PROFILE                    (TIME) float64 ...
#     PROFILE_quality_control    (TIME) float32 ...
#     PRES                       (TIME) float64 ...
#     PRES_quality_control       (TIME) float32 ...
#     DEPTH_quality_control      (TIME) float32 ...
#     TEMP                       (TIME) float64 ...
#     TEMP_quality_control       (TIME) float32 ...
#     CNDC                       (TIME) float64 ...
#     CNDC_quality_control       (TIME) float32 ...
#     PSAL                       (TIME) float64 ...
#     PSAL_quality_control       (TIME) float32 ...
#     DOX2                       (TIME) float64 ...
#     DOX2_quality_control       (TIME) float32 ...
#     DOX1                       (TIME) float64 ...
#     DOX1_quality_control       (TIME) float32 ...
#     CPHL                       (TIME) float64 ...
#     CPHL_quality_control       (TIME) float32 ...
#     CDOM                       (TIME) float64 ...
#     CDOM_quality_control       (TIME) float32 ...
#     VBSC                       (TIME) float64 ...
#     VBSC_quality_control       (TIME) float32 ...
#     BBP                        (TIME) float64 ...
#     BBP_quality_control        (TIME) float32 ...
#     IRRAD443                   (TIME) float64 ...
#     IRRAD443_quality_control   (TIME) float32 ...
#     IRRAD490                   (TIME) float64 ...
#     IRRAD490_quality_control   (TIME) float32 ...
#     IRRAD555                   (TIME) float64 ...
#     IRRAD555_quality_control   (TIME) float32 ...
#     IRRAD670                   (TIME) float64 ...
#     IRRAD670_quality_control   (TIME) float32 ...
# Attributes:
#     project:                          Integrated Marine Observing System (IMOS)
#     institution:                      ANFOG (Australian National Facility for...
#     references:                       http://www.imos.org.au; "ANFOG Data Man...
#     naming_authority:                 IMOS
#     cdm_data_type:                    Trajectory
#     data_centre:                      Australian Ocean Data Network (AODN)
#     data_centre_email:                info@aodn.org.au
#     principal_investigator:           Pattiaratchi, Charitha
#     principal_investigator_email:     chari.pattiaratchi@uwa.edu.au
#     institution_references:           http://imos.org.au/emii.html; http://im...
#     citation:                         Citation to be used in publications sho...
#     acknowledgement:                  Any users of IMOS data are required to ...
#     disclaimer:                       Data, products and services from IMOS a...
#     license:                          http://creativecommons.org/licenses/by/...
#     standard_name_vocabulary:         NetCDF Climate and Forecast (CF) Metada...
#     source:                           Glider observation
#     geospatial_lat_units:             degrees_north
#     geospatial_lon_units:             degrees_east
#     geospatial_vertical_units:        meter
#     geospatial_vertical_positive:     down
#     Conventions:                      CF-1.6,IMOS-1.4
#     title:                            Slocum G2_oxy4 glider data from the mis...
#     date_created:                     2017-11-03T08:26:00Z
#     abstract:                         This NetCDF file contains data from the...
#     comment:                          This file contains data from the follow...
#     keywords:                         Water Temperature, Conductivity, Salini...
#     geospatial_vertical_min:          -1.0029
#     geospatial_vertical_max:          198.002
#     author:                           Woo, Mun
#     processing:                       Written by MATLAB processing code versi...
#     deployment_code:                  Forster20170911
#     netcdf_version:                   4.0
#     platform_code:                    SL287
#     local_time_zone:                  10.0
#     author_email:                     anfog-ecm@uwa.edu.au
#     data_mode:                        Delayed Mode
#     geospatial_lat_min:               -33.694203333333334
#     geospatial_lat_max:               -32.162760000000006
#     geospatial_lon_min:               151.5344166666667
#     geospatial_lon_max:               152.82454166666668
#     time_coverage_start:              2017-09-11T07:10:56Z
#     time_coverage_end:                2017-10-02T01:03:28Z
#     compliance_checks_passed:         cf imos:1.4
#     compliance_checker_version:       2.3.1
#     compliance_checker_imos_version:  1.1.2
#     history:                          2017-11-06 07:08:25 UTC: passed complia...

# %% [markdown]
# ## Plot map of track

# %%
plt.figure(figsize=(12, 12))
ax1 = plt.axes(projection=ccrs.PlateCarree())
plt.plot(g1.LONGITUDE,g1.LATITUDE,transform=ccrs.PlateCarree(),color='royalblue')
plt.plot(g2.LONGITUDE,g2.LATITUDE,transform=ccrs.PlateCarree(),color='red')
plt.plot(g3.LONGITUDE,g3.LATITUDE,transform=ccrs.PlateCarree(),color='royalblue')
plt.plot(g4.LONGITUDE,g4.LATITUDE,transform=ccrs.PlateCarree(),color='red')
plt.plot(g5.LONGITUDE,g5.LATITUDE,transform=ccrs.PlateCarree(),color='royalblue')
plt.plot(g6.LONGITUDE,g6.LATITUDE,transform=ccrs.PlateCarree(),color='red')
plt.plot(g7.LONGITUDE,g7.LATITUDE,transform=ccrs.PlateCarree(),color='royalblue')
ax1.coastlines(resolution='10m')
ax1.set_extent([151.4, 152.6, -33.6, -32.4])
gl = ax1.gridlines(draw_labels=True,
             color='black', alpha=0.2, linestyle='--')
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
gl.ylabels_right = False
gl.xlabels_bottom = False
ax1.add_feature(cfeature.LAND, facecolor='0.9') #Grayscale colors can be set using 0 (black) to 1 (white)
ax1.add_feature(cfeature.LAKES, alpha=0.9)  #Alpha sets transparency (0 is transparent, 1 is solid)
ax1.add_feature(cfeature.BORDERS, zorder=10)

# %%
ts.TEMP.shape
# Out:
# (330497,)

# %% [markdown]
# ## Plot T-S

# %%
# create figure with specific size
plt.figure(figsize=(10,8))
map=cm.get_cmap('cmo.deep', 11)
# scatter TEMP vs. PSAL
plt.scatter(ts.PSAL,ts.TEMP,c=ts.DEPTH,cmap=map)
# add axis labels
plt.xlabel('Practical Salinity')
plt.ylabel('Seawater temperature [deg C]')
# reduce number of ticks
locs, labels = plt.xticks()
plt.xticks(locs[::1])
plt.colorbar(extend='both')

# %% [markdown]
# ## Plot Chla section

# %%
cmap ='ocean_r'

fig, ax = plt.subplots(figsize=(17, 5))
kw = dict(s=15, c=df['CPHL'], marker='o', edgecolor='none',cmap=cmap,vmin=0,vmax=2)
cs = ax.scatter(df.index, df['DEPTH'], **kw)

#plt.plot(g1.TIME,175,color='red')

ax.invert_yaxis()
ax.set_xlim(df.index[0], df.index[-1])
xfmt = mdates.DateFormatter('%H:%Mh\n%d-%b')
ax.xaxis.set_major_formatter(xfmt)
#pyplot.axhline(y=100, xmin=0,xmax='2017-09-16T13:00:00',color='red')
               
cbar = fig.colorbar(cs, orientation='vertical', extend='both')
cbar.ax.set_ylabel(r'Chlorophyll-a [mg.m$^{-3}$]')
ax.set_ylabel('Depth (m)');
ax.set_facecolor('black')
ax.set_ylim([200,0])

#savefig('SL287_glider_chla_section.png', dpi=300,bbox_inches='tight')
# Out:
# /home/z3526974/anaconda2/lib/python2.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# (200, 0)

# %% [markdown]
# ## Plot temperature and salinity sections

# %%
cmap = cmocean.cm.thermal

fig = plt.figure(figsize=(15,8))
ax = plt.subplot(2,1,1)

kw = dict(s=15, c=df['TEMP'], marker='o', edgecolor='none',cmap=cmap,vmin=15,vmax=20)
cs = ax.scatter(df.index, df['DEPTH'], **kw)

#plt.plot(g1.TIME,175,color='red')

ax.invert_yaxis()
ax.set_xlim(df.index[0], df.index[-1])
xfmt = mdates.DateFormatter('%H:%Mh\n%d-%b')
ax.xaxis.set_major_formatter(xfmt)
#pyplot.axhline(y=100, xmin=0,xmax='2017-09-16T13:00:00',color='red')
               
cbar = fig.colorbar(cs, orientation='vertical', extend='both')
cbar.ax.set_ylabel(r'Temperature [$^\circ$C]')
ax.set_ylabel('Depth (m)');
ax.set_facecolor('black')
ax.set_ylim([200,0])

ax = plt.subplot(2,1,2)
cmap = cmocean.cm.haline
kw = dict(s=15, c=df['PSAL'], marker='o', edgecolor='none',cmap=cmap,vmin=35.2,vmax=35.8)
cs = ax.scatter(df.index, df['DEPTH'], **kw)

#plt.plot(g1.TIME,175,color='red')

ax.invert_yaxis()
ax.set_xlim(df.index[0], df.index[-1])
xfmt = mdates.DateFormatter('%H:%Mh\n%d-%b')
ax.xaxis.set_major_formatter(xfmt)
#pyplot.axhline(y=100, xmin=0,xmax='2017-09-16T13:00:00',color='red')
               
cbar = fig.colorbar(cs, orientation='vertical', extend='both')
cbar.ax.set_ylabel(r'Salinity [PSU]')
ax.set_ylabel('Depth (m)');
ax.set_facecolor('black')
ax.set_ylim([200,0])
savefig('SL287_glider_T_S_section.png', dpi=300,bbox_inches='tight')

# %% [markdown]
# ## Plot U and V sections

# %%
plt.figure(figsize=[10,5])
df[['UCUR','VCUR']].plot(marker='o')
plt.ylabel('$m.s^{-1}$')
savefig('SL287_glider_currents_section.png', dpi=300,bbox_inches='tight')

# %% [markdown]
# ## plot timeseries of 3-day composite maps of oceancolour

# %%
chla = xr.open_dataset('/home/z3526974/Work/data/dipole_work/Ocean_colour/IMOS_aggregation_20190527T040102Z.nc',decode_times=False)

# %% [markdown]
# ### make 3-day composites for plotting

# %%
chla.time.shape
# Out:
# (13,)

# %%
c1 = chla.chl_oc3[3:5,:,:]
c2 = chla.chl_oc3[6:8,:,:]
c3 = chla.chl_oc3[9:11,:,:]
c1
# Out:
# <xarray.DataArray 'chl_oc3' (time: 2, latitude: 801, longitude: 601)>
# [962802 values with dtype=float32]
# Coordinates:
#   * latitude   (latitude) float64 -30.0 -30.01 -30.02 ... -37.98 -37.99 -38.0
#   * time       (time) float64 7.952e+04 7.952e+04
#   * longitude  (longitude) float64 149.0 149.0 149.0 149.0 ... 155.0 155.0 155.0
# Attributes:
#     flag_applied:  HISATZEN LAND CLDICE NAVFAIL
#     long_name:     Chlorophyll Concentration, OC3 Algorithm
#     units:         mg/m^3

# %% [markdown]
# ### Plot

# %%
fig = plt.figure(figsize=(18, 5))
ax1 = plt.subplot(1,3,1, projection=ccrs.PlateCarree())

kw=dict(cmap=cm.get_cmap('YlGn', 15),vmin=0,vmax=1.5,
             transform=ccrs.PlateCarree())
plt.pcolormesh(chla.longitude, chla.latitude, c1.mean(dim='time'),**kw)

ax1.coastlines(resolution='50m')
ax1.set_extent([150.5, 153, -35, -32.5])
gl = ax1.gridlines(draw_labels=True,
             color='black', alpha=0.2, linestyle='--')
gl.xlocator = mticker.FixedLocator([150.5,151,151.5,152,152.5,153])
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
gl.ylabels_right = False
gl.xlabels_bottom = False
ax1.add_feature(cfeature.LAND, facecolor='0.9') #Grayscale colors can be set using 0 (black) to 1 (white)
ax1.add_feature(cfeature.LAKES, alpha=0.9)  #Alpha sets transparency (0 is transparent, 1 is solid)
ax1.add_feature(cfeature.BORDERS, zorder=10)
plt.plot(g1.LONGITUDE,g1.LATITUDE,transform=ccrs.PlateCarree(),color='blue')
plt.plot(g2.LONGITUDE,g2.LATITUDE,transform=ccrs.PlateCarree(),color='red')
plt.plot(g3.LONGITUDE,g3.LATITUDE,transform=ccrs.PlateCarree(),color='blue')
plt.plot(g4.LONGITUDE,g4.LATITUDE,transform=ccrs.PlateCarree(),color='red')
plt.text(150.6,-32.8,'16-18 Sept',fontsize=16)

ax1 = plt.subplot(1,3,2, projection=ccrs.PlateCarree())
plt.pcolormesh(chla.longitude, chla.latitude, c2.mean(dim='time'), **kw)

ax1.coastlines(resolution='50m')
ax1.set_extent([150.5, 153, -35, -32.5])
gl = ax1.gridlines(draw_labels=True,
             color='black', alpha=0.2, linestyle='--')
gl.xlocator = mticker.FixedLocator([150.5,151,151.5,152,152.5,153])
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
gl.ylabels_right = False
gl.xlabels_bottom = False
ax1.add_feature(cfeature.LAND, facecolor='0.9') #Grayscale colors can be set using 0 (black) to 1 (white)
ax1.add_feature(cfeature.LAKES, alpha=0.9)  #Alpha sets transparency (0 is transparent, 1 is solid)
ax1.add_feature(cfeature.BORDERS, zorder=10)
plt.plot(g1.LONGITUDE,g1.LATITUDE,transform=ccrs.PlateCarree(),color='blue')
plt.plot(g2.LONGITUDE,g2.LATITUDE,transform=ccrs.PlateCarree(),color='red')
plt.plot(g3.LONGITUDE,g3.LATITUDE,transform=ccrs.PlateCarree(),color='blue')
plt.plot(g4.LONGITUDE,g4.LATITUDE,transform=ccrs.PlateCarree(),color='red')
plt.plot(g5.LONGITUDE,g5.LATITUDE,transform=ccrs.PlateCarree(),color='blue')
plt.plot(g6.LONGITUDE,g6.LATITUDE,transform=ccrs.PlateCarree(),color='red')
plt.text(150.6,-32.8,'19-21 Sept',fontsize=16)

ax1 = plt.subplot(1,3,3, projection=ccrs.PlateCarree())
cs = plt.pcolormesh(chla.longitude, chla.latitude, c3.mean(dim='time'), **kw)

ax1.coastlines(resolution='50m')
ax1.set_extent([150.5, 153, -35, -32.5])
gl = ax1.gridlines(draw_labels=True,
             color='black', alpha=0.2, linestyle='--')
gl.xlocator = mticker.FixedLocator([150.5,151,151.5,152,152.5,153])
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
gl.ylabels_right = False
gl.xlabels_bottom = False
ax1.add_feature(cfeature.LAND, facecolor='0.9') #Grayscale colors can be set using 0 (black) to 1 (white)
ax1.add_feature(cfeature.LAKES, alpha=0.9)  #Alpha sets transparency (0 is transparent, 1 is solid)
ax1.add_feature(cfeature.BORDERS, zorder=10)
plt.plot(g1.LONGITUDE,g1.LATITUDE,transform=ccrs.PlateCarree(),color='blue')
plt.plot(g2.LONGITUDE,g2.LATITUDE,transform=ccrs.PlateCarree(),color='red')
plt.plot(g3.LONGITUDE,g3.LATITUDE,transform=ccrs.PlateCarree(),color='blue')
plt.plot(g4.LONGITUDE,g4.LATITUDE,transform=ccrs.PlateCarree(),color='red')
plt.plot(g5.LONGITUDE,g5.LATITUDE,transform=ccrs.PlateCarree(),color='blue')
plt.plot(g6.LONGITUDE,g6.LATITUDE,transform=ccrs.PlateCarree(),color='red')
plt.plot(g7.LONGITUDE,g7.LATITUDE,transform=ccrs.PlateCarree(),color='blue')
plt.text(150.6,-32.8,'22-24 Sept',fontsize=16)
fig.subplots_adjust(right=0.83)
cbar_ax = fig.add_axes([0.85, 0.15, 0.01, 0.7])
fig.colorbar(cs, cax=cbar_ax, extend='both')
cbar_ax.set_ylabel(r'Chlorophyll-a [mg.m$^{-3}$]')
#savefig('chla_spatial_tseries.png', dpi=300,bbox_inches='tight')
# Out:
# Text(0,0.5,'Chlorophyll-a [mg.m$^{-3}$]')
